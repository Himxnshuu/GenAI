# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gemini-2.5-flash-lite")
model
# Out:
# /var/folders/qk/w2dppmc97_74bgsxzbp66kdw0000gn/T/ipykernel_2515/3169166334.py:2: DeprecationWarning: Inferred `model_provider='google_vertexai'` from 'gemini-2.5-flash-lite'. This default will change to 'google_genai' in the next major release.To keep current behavior, pass `model_provider='google_vertexai'` (or use the prefix form, e.g. 'google_vertexai:gemini-2.5-flash-lite'); for AI Studio / Gemini API, use 'google_genai' instead.
#   model = init_chat_model("gemini-2.5-flash-lite")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Self Gen AI/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:118, in _import_module(module, class_name)
#     117 try:
# --> 118     return importlib.import_module(module)
#     119 except ImportError as e:
#     120     # Extract package name from module path (e.g., "langchain_azure_ai.chat_models"
#     121     # becomes "langchain-azure-ai")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1406, in _gcd_import(name, package, level)
#    1404     if level > 0:
#    1405         name = _resolve_name(name, package, level)
# -> 1406     return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369             module = sys.modules.get(name, _NEEDS_LOADING)
#    1370             if module is _NEEDS_LOADING:
# -> 1371                 return _find_and_load_unlocked(name, import_)
#    1372
#
# File <frozen importlib._bootstrap>:1335, in _find_and_load_unlocked(name, import_)
#    1333     spec = _find_spec(name, path)
#    1334     if spec is None:
# -> 1335         raise ModuleNotFoundError(f'{_ERR_MSG_PREFIX}{name!r}', name=name)
#    1336     else:
#
# ModuleNotFoundError: No module named 'langchain_google_vertexai'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 from langchain.chat_models import init_chat_model
# ----> 2 model = init_chat_model("gemini-2.5-flash-lite")
#
# File ~/Self Gen AI/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:494, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     486     warnings.warn(
#     487         f"{config_prefix=} has been set but no fields are configurable. Set "
#     488         f"`configurable_fields=(...)` to specify the model params that are "
#     489         f"configurable.",
#     490         stacklevel=2,
#     491     )
#     493 if not configurable_fields:
# --> 494     return _init_chat_model_helper(
#     495         cast("str", model),
#     496         model_provider=model_provider,
#     497         **kwargs,
#     498     )
#     499 if model:
#     500     kwargs["model"] = model
#
# File ~/Self Gen AI/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:517, in _init_chat_model_helper(model, model_provider, **kwargs)
#     510 def _init_chat_model_helper(
#     511     model: str,
#     512     *,
#     513     model_provider: str | None = None,
#     514     **kwargs: Any,
#     515 ) -> BaseChatModel:
#     516     model, model_provider = _parse_model(model, model_provider)
# --> 517     creator_func = _get_chat_model_creator(model_provider)
#     518     return creator_func(model=model, **kwargs)
#
# File ~/Self Gen AI/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:158, in _get_chat_model_creator(provider)
#     156 pkg, class_name, creator_func = _BUILTIN_PROVIDERS[provider]
#     157 try:
# --> 158     module = _import_module(pkg, class_name)
#     159 except ImportError as e:
#     160     if provider != "ollama":
#
# File ~/Self Gen AI/.venv/lib/python3.14/site-packages/langchain/chat_models/base.py:127, in _import_module(module, class_name)
#     122 pkg = module.split(".", maxsplit=1)[0].replace("_", "-")
#     123 msg = (
#     124     f"Initializing {class_name} requires the {pkg} package. Please install it "
#     125     f"with `pip install {pkg}`"
#     126 )
# --> 127 raise ImportError(msg) from e
#
# ImportError: Initializing ChatVertexAI requires the langchain-google-vertexai package. Please install it with `pip install langchain-google-vertexai`
